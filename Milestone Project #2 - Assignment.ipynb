# %%
# Milestone Project 2 (Assignment)

# %%
# Import the random module. Global Variables
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

# %%
# Create Card Class
class Card():

    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        
    def __str__(self):
        return self.rank + ' of ' + self.suit

# %%
# Create Deck Class
class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
        # Nested for loop
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))  # build Card objects and add them to the list
    
    def __str__(self):
        deck_comp = ''  # start with an empty string
        for card in self.deck:
            deck_comp += '\n '+card.__str__() # add each Card object's print string
        return 'The deck has:' + deck_comp

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_card = self.deck.pop()
        return single_card # return self.deck.pop()

# %%
# Test my work so far
# Perfect!
my_deck = Deck()
my_deck.shuffle()
print(my_deck)
# Out:
# The deck has:
#  Ace of Spades
#  Ace of Hearts
#  Queen of Spades
#  Three of Diamonds
#  Ten of Clubs
#  Five of Hearts
#  Two of Clubs
#  Four of Diamonds
#  Nine of Hearts
#  Ten of Hearts
#  Ace of Clubs
#  Seven of Diamonds
#  Eight of Spades
#  Six of Spades
#  King of Diamonds
#  Three of Hearts
#  Two of Spades
#  Seven of Hearts
#  Six of Diamonds
#  Two of Hearts
#  Eight of Clubs
#  King of Spades
#  Jack of Diamonds
#  King of Clubs
#  Eight of Diamonds
#  Eight of Hearts
#  Nine of Clubs
#  King of Hearts
#  Six of Hearts
#  Four of Hearts
#  Jack of Spades
#  Ace of Diamonds
#  Three of Spades
#  Six of Clubs
#  Jack of Hearts
#  Seven of Clubs
#  Queen of Diamonds
#  Jack of Clubs
#  Two of Diamonds
#  Four of Clubs
#  Three of Clubs
#  Nine of Diamonds
#  Five of Diamonds
#  Nine of Spades
#  Ten of Spades
#  Seven of Spades
#  Queen of Hearts
#  Five of Clubs
#  Four of Spades
#  Five of Spades
#  Queen of Clubs
#  Ten of Diamonds

# %%
# So far: we have set up global variables at the top, and also imported the random library. The global variables are tuples to represent the suits, ranks and values.

# %%
# We created a class for the card itself.

# %%
# For the deck class we wanted to leverage the card class.

# %%
# Create a Hand Class
class Hand:
    def __init__(self):
        self.cards = []  # start with an empty list as we did in the Deck class
        self.value = 0   # start with zero value
        self.aces = 0    # add an attribute to keep track of aces
    
    def add_card(self,card): # Card passed in.
        # From the Deck.deal()
        self.cards.append(card)
        # adjusting our value to the card that was added to the list.
        self.value += values[card.rank] 
        # Take that cards rank, look it up in the values dictionary. Then add that to our self.value.
        if card.rank == 'Ace':
            self.aces += 1  # add to self.aces
    
    def adjust_for_ace(self):
        # If total value greater than(>) 21 and i still have an ace
        # Then change my ace to be a 1 instead of an 11(Starts off as)
        while self.value > 21 and self.aces: # 'and self.aces' using an integer as truthyness (and self.aces > 0)
            self.value -= 10
            self.aces -= 1

# %%
# Version 1
test_deck = Deck()
test_deck.shuffle()
# Player
test_player = Hand()
# Deal one card from the deck Card(suit,rank)
test_player.add_card(test_deck.deal())
test_player.add_card(test_deck.deal())
test_player.value
# Out:
# 15

# %%
# Version 2
test_deck = Deck()
test_deck.shuffle()
# Player
test_player = Hand()
# Deal one card from the deck Card(suit,rank)
pulled_card = test_deck.deal()
print(pulled_card)
test_player.add_card(pulled_card)
print(test_player.value)
# Out:
# Two of Diamonds
# 2

# %%
for card in test_player.cards:
    print(card)
# Out:
# Five of Clubs
# Ten of Spades

# %%
# Instance of Truthyness. 
zero = 0
one = 1
two = 2

# %%
# Check if they are true or not.
if one: # 0 the integer is treated as false, and other numbers that are not 0 (1,2,3,etc) are treated as true.
    print('True.')
# Notice: We dont get anything printed out.
# Out:
# True.

# %%
# Create a Chips Class 
class Chips:
    # Keep track of some total, and the current bet they have placed.
    def __init__(self,total = 100): # (self)
        self.total = total  # This can be set to a default value or supplied by a user input (self.total = 100)
        self.bet = 0
    # Either add to that bet if they win it.    
    def win_bet(self):
        self.total += self.bet
    # Or subtract to that bet if they lose it.
    def lose_bet(self):
        self.total -= self.bet

# %%
# Create a Take Bet Class
 # Functions for actually playing the game.( alot of flexibility) 
def take_bet(chips):
    
    while True:
        try:
            chips.bet = int(input('How many chips would you like to bet? '))
        except ValueError:
            print('Sorry, an integer is required for the bet.')
        else:
            if chips.bet > chips.total:
                print("Sorry, your bet can't exceed",chips.total) # ("Sorry, your bet can't exceed {}".format(chips.total))
            else:
                break

# %%
# Create a Hit Class
def hit(deck,hand):
    # Add a card to the hand from the actual deck
    hand.add_card(deck.deal())
    hand.adjust_for_ace()
    # Adjust hand for ace (1/11)

# %%
# Create a Hit or Stand Class
def hit_or_stand(deck,hand):
    global playing  # to control an upcoming while loop
    
    while True:
        x = input("Would you like to Hit or Stand? Enter 'h' or 's' ")
        
        if x[0].lower() == 'h':
            hit(deck,hand)  # hit() function defined above

        elif x[0].lower() == 's':
            print("Player stands. Dealer is playing.")
            playing = False # break

        else:
            print("Sorry, please enter a 'h' or an 's' only.")
            continue
        break

# %%
# Create a Function to display cards
def show_some(player,dealer):
    
    # Show only one of the dealer's cards.
    print("\nDealer's Hand: ")
    print(" <card hidden> ")
    # Show all (2 cards at the beginning) of the player's hand/cards.
    # dealer.card[0] we are going to show dealer.cards one
    print('',dealer.cards[1])  
    print("\nPlayer's Hand:", *player.cards, sep='\n ') # Going to loop through every item & then print it out. and put in a new line every time you show.
    
def show_all(player,dealer): # This is technically done at the end. When you want to calculate who won.
    # Show all the dealer's cards.
    print("\nDealer's Hand:", *dealer.cards, sep='\n ') # Going to loop through every item & then print it out. and put in a new line every time you show.
    # Calculate and display value (J+K == 20)
    print("Dealer's Hand =",dealer.value)
    # Show all the players cards.
    print("\nPlayer's Hand:", *player.cards, sep='\n ') # Functionality put inside of the print function
    print("Player's Hand =",player.value)

# %%
# Create an End of Game Scenario
def player_busts(player,dealer,chips):
    print("Player busts!")
    chips.lose_bet()

def player_wins(player,dealer,chips):
    print("Player wins!")
    chips.win_bet()

def dealer_busts(player,dealer,chips):
    print("Dealer busts!")
    chips.win_bet()
    
def dealer_wins(player,dealer,chips):
    print("Dealer wins!")
    chips.lose_bet()
    
def push(player,dealer):
    print("Dealer and Player tie! It's a push.")

# %%
# Create The Logic for Game
while True:
    # Print an opening statement
    print('Welcome to BlackJack! Get as close to 21 as you can without going over!\n\
    Dealer hits until she reaches 17. Aces count as 1 or 11.')
    
    # Create & shuffle the deck, deal two cards to each player
    deck = Deck()
    deck.shuffle()
    
    player_hand = Hand()
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())
    
    dealer_hand = Hand()
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
            
    # Set up the Player's chips
    player_chips = Chips()  # remember the default value is 100 (its being reset here)  
    
    # Prompt the Player for their bet
    take_bet(player_chips)
    
    # Show cards (but keep one dealer card hidden)
    show_some(player_hand,dealer_hand)
    
    while playing:  # recall this variable from our hit_or_stand function
        
        # Prompt for Player to Hit or Stand
        hit_or_stand(deck,player_hand) 
        
        # Show cards (but keep one dealer card hidden)
        show_some(player_hand,dealer_hand)  
        
        # If player's hand exceeds 21, run player_busts() and break out of loop
        if player_hand.value > 21:
            player_busts(player_hand,dealer_hand,player_chips)
            break        


    # If Player hasn't busted, play Dealer's hand until Dealer reaches 17 
    if player_hand.value <= 21:
        
        while dealer_hand.value < 17: # Soft Seventeen Rule used here.
            hit(deck,dealer_hand)    
    
        # Show all cards
        show_all(player_hand,dealer_hand)
        
        # Run different winning scenarios
        if dealer_hand.value > 21:
            dealer_busts(player_hand,dealer_hand,player_chips)

        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_hand,dealer_hand,player_chips)

        elif dealer_hand.value < player_hand.value:
            player_wins(player_hand,dealer_hand,player_chips)

        else:
            push(player_hand,dealer_hand)        
    
    # Inform Player of their chips total 
    print("\nPlayer's winnings stand at",player_chips.total)
    
    # Ask to play again
    new_game = input("Would you like to play another hand? Enter 'y' or 'n' ")
    
    if new_game[0].lower()=='y':
        playing=True
        continue
    else:
        print("Thanks for playing!")
        break
# Out:
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 700
# Sorry, your bet can't exceed 100
# How many chips would you like to bet? 50
#
# Dealer's Hand:
#  <card hidden>
#  Two of Clubs
#
# Player's Hand:
#  Six of Hearts
#  Ten of Hearts
# Would you like to Hit or Stand? Enter 'h' or 's' s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#  Two of Clubs
#
# Player's Hand:
#  Six of Hearts
#  Ten of Hearts
#
# Dealer's Hand:
#  Seven of Spades
#  Two of Clubs
#  Ten of Diamonds
# Dealer's Hand = 19
#
# Player's Hand:
#  Six of Hearts
#  Ten of Hearts
# Player's Hand = 16
# Dealer wins!
#
# Player's winnings stand at 50
# Would you like to play another hand? Enter 'y' or 'n' y
# Welcome to BlackJack! Get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# ...
